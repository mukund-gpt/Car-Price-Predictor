# %%
import pandas as pd
import numpy as np

# %%
car=pd.read_csv("Cleaned car.csv")

# %%
car.describe()
# Out:
#        Unnamed: 0         year         Price     kms_driven
# count  815.000000   815.000000  8.150000e+02     815.000000
# mean   407.000000  2012.442945  4.017933e+05   46277.096933
# std    235.414528     4.005079  3.815888e+05   34318.459638
# min      0.000000  1995.000000  3.000000e+04       0.000000
# 25%    203.500000  2010.000000  1.750000e+05   27000.000000
# 50%    407.000000  2013.000000  2.999990e+05   41000.000000
# 75%    610.500000  2015.000000  4.900000e+05   56879.000000
# max    814.000000  2019.000000  3.100000e+06  400000.000000

# %%
car=car.drop(columns='Unnamed: 0')

# %% [markdown]
# MODEL

# %%
X=car.drop(columns='Price')
y=car['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train , y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),remainder='passthrough')

# %%
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['name', 'company',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)
y_pred
# Out:
# array([ 330349.97088784, 2183828.30922791,  386045.63455258,
#         355271.11858245,  356439.88722055,  293337.47651827,
#        1151254.58196981,  717668.63506866,  434237.81378088,
#         239174.1705545 ,  330666.51075006,  201600.91096525,
#         423282.71367788,  172695.89120693,  413120.38123855,
#          -8232.38706484,  219914.28176425,  455634.05940762,
#         358489.93936937,  882058.09288997,  483762.27475572,
#         813835.40942045,  322058.18104395,  412552.29648246,
#         177419.04689825,  343375.48231255,  238858.38912676,
#         192558.87776606,  342928.52926034,  300322.36392917,
#         281079.62051369,  526812.45682472,  358567.20179764,
#         769016.75096674,  467258.44120434,  449044.38964269,
#         507435.21309981,  212112.9972583 ,  588121.48627406,
#         485744.11822357,  584217.5460417 ,  452245.02797604,
#         417534.81546725,  361581.35877777,  254352.2582342 ,
#         198709.62758171,  392638.6459436 ,  363318.86570134,
#         336557.6106011 ,  322136.48748176,  198531.35728778,
#         394129.45142525,  281421.62957702,  428978.48831004,
#         363318.86570134,  612384.00401672,  495727.65439075,
#         300322.36392917,  304987.36590216,  529405.45114604,
#         750181.17685635, 1481930.65773147,  268529.6295014 ,
#         563723.02786748,  493948.47559087,  308355.82446817,
#         238858.38912676, 1067829.58363821,  455404.54264583,
#         611010.38896817,  176480.79846697,  488163.13915904,
#         900080.61208251,  224380.25540663,  125598.13431071,
#        -158225.21830492,  156800.41834279,  495727.65439075,
#         194331.76220064,  352131.84476129,  512962.25701385,
#         303148.47814653, 2183828.30922791,  101791.89160505,
#        1323937.92546969,   34424.10659079,  633489.61714219,
#         599509.29455607, 1332921.72231817,  717668.63506866,
#         533380.20628057,  379654.18098587,  364337.43663339,
#         239174.1705545 ,  540831.08701316,   85457.39740174,
#         471797.15034337,  181950.08763614,  454605.76829506,
#         -18947.55499639,   40744.16225571,  223300.88083117,
#         425552.0682474 ,   78271.10793161,  255149.17381696,
#         -71557.50479373,  -18286.53524943,  193403.75673486,
#         154312.53009836,  606607.96745561,  183142.60395578,
#         500175.75541656,  272049.0497196 ,  172485.7741014 ,
#         298347.30481298,  259637.63088543,  415879.58535573,
#         447809.06002599,  440296.69212099,  273006.17878672,
#         368336.96559121,  381491.97996142,  498851.53491747,
#         503851.51993486,  189892.82862944,   76085.9269348 ,
#         759447.76508573,  791359.14784231,  326777.78305262,
#         196489.86330737,  610787.87628096,   60622.76713195,
#         489297.81644379,  954214.98438293,  130578.91634561,
#         169160.44304038,  641636.1197115 ,  414058.9688742 ,
#          81569.53050369,  459241.23797055,  329767.11996661,
#         668341.9293967 ,  585578.24366134,  229023.19069104,
#         548827.29519287,  211319.76342291,  519657.97907092,
#         325931.54511754,  443696.21705147,   63196.49716593,
#         303655.06524872,  379328.63447991,  290351.24658646,
#         349877.25315907,  203656.31635727,  276896.11851186,
#         291974.94767895,  303198.12246045,   70439.34671534,
#         235454.35727249,  699367.58744601,  168043.19854297,
#         176480.79846697])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6022669493194506

# %%
scores=[]
for i in range(1000):
    X_train, X_test, y_train , y_test=train_test_split(X,y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 433

# %%
scores[np.argmax(scores)]
# Out:
# 0.8457046438151008

# %%
X_train, X_test, y_train , y_test=train_test_split(X,y,test_size=0.2,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8457046438151008

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegression.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']],columns=['name','company','year','kms_driven','fuel_type']))
# Out:
# array([458899.18891749])
